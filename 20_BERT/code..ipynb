# %%
# First, let's check TensorFlow version and install compatible tensorflow_text
import tensorflow as tf
print(f"TensorFlow version: {tf.__version__}")

# Install compatible version of tensorflow_text
# For TF 2.10.x, use tensorflow_text 2.10.x
! pip install tensorflow_text==2.10.0 --force-reinstall
# Out:
# TensorFlow version: 2.20.0
# WARNING: Error parsing dependencies of numpy: [Errno 2] No such file or directory: 'c:\\users\\nishc\\anaconda3\\envs\\py_gpu\\lib\\site-packages\\numpy-1.23.5.dist-info\\METADATA'
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Nishc\anaconda3\envs\py_gpu\Lib\site-packages\~rapt'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Nishc\anaconda3\envs\py_gpu\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
#     WARNING: No metadata found in c:\users\nishc\anaconda3\envs\py_gpu\lib\site-packages
# error: uninstall-no-record-file
#
# × Cannot uninstall numpy 1.23.5
# ╰─> The package's contents are unknown: no RECORD file was found for numpy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps numpy==1.23.5
# ...
#   Using cached tensorflow_text-2.10.0-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# ...

# %%
# Install the latest available tensorflow_text version
! pip install tensorflow_text==2.10.0 --force-reinstall

# Try importing the modules
try:
    import tensorflow_hub as hub
    import tensorflow_text as text
    print("✅ Successfully imported tensorflow_hub and tensorflow_text!")
    print(f"TensorFlow Hub version: {hub.__version__}")
    print(f"TensorFlow Text version: {text.__version__}")
except ImportError as e:
    print(f"❌ Import error: {e}")
    print("This might be due to version compatibility issues.")
# Out:
# ...
#   Using cached tensorflow_text-2.10.0-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached tensorflow_hub-0.16.1-py2.py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached tensorflow-2.10.1-cp39-cp39-win_amd64.whl.metadata (3.1 kB)
# ...
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached h5py-3.14.0-cp39-cp39-win_amd64.whl.metadata (2.7 kB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...

# %%
# Test if the imports work now
import tensorflow_hub as hub
import tensorflow_text as text
print("✅ Imports successful!")
print(f"TensorFlow Hub version: {hub.__version__}")
print(f"TensorFlow Text version: {text.__version__}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Test if the imports work now
#       2 import tensorflow_hub as hub
# ----> 3 import tensorflow_text as text
#       4 print("✅ Imports successful!")
#       5 print(f"TensorFlow Hub version: {hub.__version__}")
#
# File c:\Users\Nishc\anaconda3\envs\py_gpu\lib\site-packages\tensorflow_text\__init__.py:20
#      17 from tensorflow.python.util.all_util import remove_undocumented
#      19 # pylint: disable=wildcard-import
# ---> 20 from tensorflow_text.core.pybinds import tflite_registrar
#      21 from tensorflow_text.python import keras
#      22 from tensorflow_text.python import metrics
#
# ImportError: DLL load failed while importing tflite_registrar: The specified procedure could not be found.

# %%
preprocess_url = "https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3"
encoder_url = "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4"

# %%
bert_preprocess_model = hub.KerasLayer(preprocess_url)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Nishc\anaconda3\envs\py_gpu\lib\site-packages\tensorflow\python\framework\ops.py:3105, in Graph.op_def_for_type(self, type)
#    3104 try:
# -> 3105   return self._op_def_cache[type]
#    3106 except KeyError:
#
# KeyError: 'CaseFoldUTF8'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 bert_preprocess_model = hub.KerasLayer(preprocess_url)
#
# File c:\Users\Nishc\anaconda3\envs\py_gpu\lib\site-packages\tensorflow_hub\keras_layer.py:165, in KerasLayer.__init__(self, handle, trainable, arguments, _sentinel, tags, signature, signature_outputs_as_dict, output_key, output_shape, load_options, **kwargs)
#     161   self._output_shape = data_structures.NoDependency(
# ...

# %%
text_test = ['nice movie indeed','I love python programming']
text_preprocessed = bert_preprocess_model(text_test)
text_preprocessed.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 text_test = ['nice movie indeed','I love python programming']
# ----> 2 text_preprocessed = bert_preprocess_model(text_test)
#       3 text_preprocessed.keys()
#
# NameError: name 'bert_preprocess_model' is not defined

# %%
text_preprocessed['input_mask']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 text_preprocessed['input_mask']
#
# NameError: name 'text_preprocessed' is not defined

# %%
text_preprocessed['input_type_ids']

# %%
text_preprocessed['input_word_ids']

# %%
bert_model = hub.KerasLayer(encoder_url)

# %%
bert_results = bert_model(text_preprocessed)

# %%
bert_results.keys()

# %%
bert_results['sequence_output']

# %%
len(bert_results['encoder_outputs'])

# %%
bert_results['encoder_outputs'][-1] == bert_results['sequence_output']

# %%
bert_results['encoder_outputs']
